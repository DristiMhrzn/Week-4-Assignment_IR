# %%
import os
import re
from collections import defaultdict
from math import log

# %%
#Preprocessing
def preprocess(text):
    """Tokenize and lowercase text."""
    return re.findall(r'\b\w+\b', text.lower())

# %%
#Loading documents
def load_documents(folder_path):
    """Load all .txt files in the folder and preprocess them."""
    docs = {}
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            with open(os.path.join(folder_path, filename), 'r', encoding='utf-8') as f:
                docs[filename] = preprocess(f.read())
    return docs

# %%
#loading queries
def load_queries(query_file_path):
    """Load queries from a .txt file (one query per line)."""
    with open(query_file_path, 'r', encoding='utf-8') as f:
        return [line.strip() for line in f.readlines()]

# %%
#computing statistics
def compute_statistics(docs):
    """Compute TF, DF, document length, and average document length."""
    term_freq = defaultdict(lambda: defaultdict(int))
    doc_freq = defaultdict(int)
    doc_len = {}
    total_terms = 0

    for doc_id, words in docs.items():
        doc_len[doc_id] = len(words)
        total_terms += len(words)

        unique_terms = set(words)

        for w in words:
            term_freq[doc_id][w] += 1

        for w in unique_terms:
            doc_freq[w] += 1

    avg_len = total_terms / len(docs)

    return term_freq, doc_freq, doc_len, avg_len

# %%
#BM25 Scoring
def bm25_score(query_terms, term_freq, doc_freq, doc_len, avg_len, total_docs, k1=1.5, b=0.75):
    """Compute BM25 scores."""
    scores = {}

    for doc_id in term_freq:
        score = 0

        for term in query_terms:
            if term in term_freq[doc_id]:
                tf = term_freq[doc_id][term]
                df = doc_freq.get(term, 0)

                idf = log((total_docs - df + 0.5) / (df + 0.5) + 1)

                numerator = tf * (k1 + 1)
                denominator = tf + k1 * (1 - b + b * (doc_len[doc_id] / avg_len))

                score += idf * (numerator / denominator)

        scores[doc_id] = score

    return scores

# %%
#Jelinek Mercer Language Model Scoring
def jm_score(query_terms, term_freq, doc_len, collection_freq, collection_len, lam=0.7):
    """Compute Jelinek-Mercer smoothing LM score."""
    scores = {}

    for doc_id in term_freq:
        score = 1.0

        for term in query_terms:
            p_doc = term_freq[doc_id].get(term, 0) / doc_len[doc_id]
            p_coll = collection_freq.get(term, 0) / collection_len

            p_final = (1 - lam) * p_doc + lam * p_coll

            if p_final > 0:
                score *= p_final

        scores[doc_id] = score

    return scores

# %%
#Ranking result
def rank_results(scores, top_k=0):
    """
    Rank documents based on scores.
    top_k = 0 --> show all documents.
    """
    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    if top_k == 0:
        return ranked
    return ranked[:top_k]

# %%
def retrieve_documents(folder_path, query_file_path, top_k=0):
    """Main retrieval pipeline."""
    docs = load_documents(folder_path)
    queries = load_queries(query_file_path)

    term_freq, doc_freq, doc_len, avg_len = compute_statistics(docs)
    total_docs = len(docs)

    # Build collection model for LM
    collection_freq = defaultdict(int)
    collection_len = 0

    for doc_id in docs:
        for term in docs[doc_id]:
            collection_freq[term] += 1
            collection_len += 1

    # Process queries
    for query in queries:
        print("\n==============================================")
        print(f"QUERY: {query}")
        print("==============================================")

        query_terms = preprocess(query)

        # BM25
        bm25_scores = bm25_score(query_terms, term_freq, doc_freq, doc_len, avg_len, total_docs)
        bm25_ranked = rank_results(bm25_scores, top_k)

        print("\n--- BM25 RESULTS ---")
        for doc, score in bm25_ranked:
            print(f"{doc}: {score:.5f}")

        # LM Jelinek-Mercer
        jm_scores = jm_score(query_terms, term_freq, doc_len, collection_freq, collection_len)
        jm_ranked = rank_results(jm_scores, top_k)

        print("\n--- Jelinek-Mercer RESULTS ---")
        for doc, score in jm_ranked:
            print(f"{doc}: {score:.12f}")

        print("\n----------------------------------------------\n")

# %%
#Execution
folder_path = r"C:\Users\Acer\Desktop\Week4 IR\Trump Speechs"
query_file_path = r"C:\Users\Acer\Desktop\Week4 IR\queries1.txt"

TOP_K = 10    

retrieve_documents(folder_path, query_file_path, top_k=TOP_K)
# Out:
# ==============================================
# QUERY: to
# ==============================================
#
# --- BM25 RESULTS ---
# speech_30.txt: 0.02172
# speech_3.txt: 0.02172
# speech_19.txt: 0.02172
# speech_41.txt: 0.02171
# speech_48.txt: 0.02171
# speech_5.txt: 0.02169
# speech_10.txt: 0.02169
# speech_13.txt: 0.02168
# speech_16.txt: 0.02168
# speech_45.txt: 0.02168
#
# --- Jelinek-Mercer RESULTS ---
# speech_13.txt: 0.035880054297
# speech_48.txt: 0.034708929924
# speech_41.txt: 0.034708269216
# speech_30.txt: 0.034319962811
# speech_43.txt: 0.034294999265
# speech_23.txt: 0.034098458815
# speech_50.txt: 0.033838199610
# speech_3.txt: 0.033777707442
# speech_46.txt: 0.033591370642
# speech_16.txt: 0.033439693216
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: america strong
# ==============================================
#
# --- BM25 RESULTS ---
# speech_2.txt: 0.63893
# speech_13.txt: 0.60554
# speech_23.txt: 0.58361
# speech_46.txt: 0.56722
# speech_49.txt: 0.56634
# speech_29.txt: 0.55812
# speech_35.txt: 0.55484
# speech_7.txt: 0.53745
# speech_16.txt: 0.53644
# speech_36.txt: 0.51126
#
# --- Jelinek-Mercer RESULTS ---
# speech_13.txt: 0.000003982968
# speech_2.txt: 0.000003027846
# speech_46.txt: 0.000002515646
# speech_51.txt: 0.000002411980
# speech_49.txt: 0.000002398708
# speech_35.txt: 0.000002312836
# speech_7.txt: 0.000002192639
# speech_23.txt: 0.000002110305
# speech_29.txt: 0.000002087741
# speech_42.txt: 0.000002037025
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: to bring us
# ==============================================
#
# --- BM25 RESULTS ---
# speech_29.txt: 0.43924
# speech_36.txt: 0.43906
# speech_0.txt: 0.43701
# speech_25.txt: 0.43553
# speech_3.txt: 0.41977
# speech_16.txt: 0.41845
# speech_32.txt: 0.41347
# speech_15.txt: 0.40758
# speech_41.txt: 0.40607
# speech_46.txt: 0.40562
#
# --- Jelinek-Mercer RESULTS ---
# speech_3.txt: 0.000000084950
# speech_29.txt: 0.000000078327
# speech_0.txt: 0.000000078035
# speech_36.txt: 0.000000076596
# speech_16.txt: 0.000000074074
# speech_25.txt: 0.000000072858
# speech_46.txt: 0.000000071961
# speech_15.txt: 0.000000071783
# speech_2.txt: 0.000000068622
# speech_32.txt: 0.000000064359
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: white
# ==============================================
#
# --- BM25 RESULTS ---
# speech_49.txt: 0.86121
# speech_14.txt: 0.78236
# speech_27.txt: 0.77163
# speech_24.txt: 0.74604
# speech_47.txt: 0.72437
# speech_5.txt: 0.68223
# speech_39.txt: 0.66136
# speech_10.txt: 0.64829
# speech_37.txt: 0.63823
# speech_7.txt: 0.63315
#
# --- Jelinek-Mercer RESULTS ---
# speech_49.txt: 0.000745446193
# speech_14.txt: 0.000624873439
# speech_27.txt: 0.000600842286
# speech_24.txt: 0.000551849243
# speech_47.txt: 0.000517556613
# speech_5.txt: 0.000464389192
# speech_28.txt: 0.000449359392
# speech_39.txt: 0.000442998818
# speech_23.txt: 0.000431115276
# speech_10.txt: 0.000430911422
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: future i
# ==============================================
#
# --- BM25 RESULTS ---
# speech_20.txt: 0.73624
# speech_10.txt: 0.70225
# speech_11.txt: 0.69551
# speech_12.txt: 0.69537
# speech_21.txt: 0.66370
# speech_44.txt: 0.65322
# speech_14.txt: 0.65211
# speech_43.txt: 0.64365
# speech_52.txt: 0.63779
# speech_33.txt: 0.62389
#
# --- Jelinek-Mercer RESULTS ---
# speech_20.txt: 0.000030397562
# speech_11.txt: 0.000027027279
# speech_10.txt: 0.000026943112
# speech_15.txt: 0.000025671285
# speech_21.txt: 0.000022821281
# speech_12.txt: 0.000020963869
# speech_52.txt: 0.000020549770
# speech_14.txt: 0.000020410634
# speech_55.txt: 0.000019602270
# speech_27.txt: 0.000019555917
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: new hope i
# ==============================================
#
# --- BM25 RESULTS ---
# speech_15.txt: 2.09531
# speech_53.txt: 1.80383
# speech_19.txt: 1.68193
# speech_8.txt: 1.66584
# speech_54.txt: 1.66129
# speech_12.txt: 1.63318
# speech_13.txt: 1.46386
# speech_27.txt: 1.38109
# speech_25.txt: 1.33898
# speech_24.txt: 1.32652
#
# --- Jelinek-Mercer RESULTS ---
# speech_15.txt: 0.000000051576
# speech_53.txt: 0.000000021396
# speech_8.txt: 0.000000021035
# speech_13.txt: 0.000000020544
# speech_27.txt: 0.000000020439
# speech_24.txt: 0.000000018549
# speech_25.txt: 0.000000018023
# speech_21.txt: 0.000000017394
# speech_12.txt: 0.000000016900
# speech_19.txt: 0.000000016433
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: a
# ==============================================
#
# --- BM25 RESULTS ---
# speech_8.txt: 0.02157
# speech_0.txt: 0.02156
# speech_6.txt: 0.02152
# speech_19.txt: 0.02150
# speech_2.txt: 0.02149
# speech_39.txt: 0.02144
# speech_9.txt: 0.02144
# speech_1.txt: 0.02143
# speech_51.txt: 0.02143
# speech_21.txt: 0.02140
#
# --- Jelinek-Mercer RESULTS ---
# speech_51.txt: 0.018850342977
# speech_0.txt: 0.018729381896
# speech_8.txt: 0.018729249216
# speech_6.txt: 0.018654675270
# speech_53.txt: 0.018639765351
# speech_21.txt: 0.018545923709
# speech_50.txt: 0.018532825887
# speech_2.txt: 0.018495209177
# speech_1.txt: 0.018369946573
# speech_39.txt: 0.018297519362
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: who have
# ==============================================
#
# --- BM25 RESULTS ---
# speech_3.txt: 0.04133
# speech_7.txt: 0.04131
# speech_22.txt: 0.04120
# speech_20.txt: 0.04110
# speech_16.txt: 0.04106
# speech_9.txt: 0.04072
# speech_28.txt: 0.04071
# speech_34.txt: 0.04070
# speech_21.txt: 0.04064
# speech_11.txt: 0.04060
#
# --- Jelinek-Mercer RESULTS ---
# speech_22.txt: 0.000051332566
# speech_28.txt: 0.000048132960
# speech_3.txt: 0.000047286905
# speech_16.txt: 0.000044413613
# speech_7.txt: 0.000043114504
# speech_20.txt: 0.000042976825
# speech_27.txt: 0.000042394564
# speech_21.txt: 0.000041801748
# speech_55.txt: 0.000041389893
# speech_34.txt: 0.000040566108
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: these patriotic men
# ==============================================
#
# --- BM25 RESULTS ---
# speech_22.txt: 4.11873
# speech_27.txt: 3.32425
# speech_21.txt: 3.20470
# speech_46.txt: 2.73749
# speech_32.txt: 2.69661
# speech_30.txt: 2.58498
# speech_29.txt: 2.43055
# speech_40.txt: 2.41867
# speech_13.txt: 0.95860
# speech_35.txt: 0.84564
#
# --- Jelinek-Mercer RESULTS ---
# speech_22.txt: 0.000000000998
# speech_21.txt: 0.000000000397
# speech_27.txt: 0.000000000198
# speech_30.txt: 0.000000000171
# speech_46.txt: 0.000000000121
# speech_32.txt: 0.000000000119
# speech_29.txt: 0.000000000104
# speech_40.txt: 0.000000000082
# speech_13.txt: 0.000000000069
# speech_15.txt: 0.000000000049
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: education
# ==============================================
#
# --- BM25 RESULTS ---
# speech_18.txt: 1.27148
# speech_30.txt: 1.12202
# speech_43.txt: 1.10427
# speech_19.txt: 1.05043
# speech_52.txt: 1.03367
# speech_10.txt: 0.99399
# speech_15.txt: 0.90662
# speech_24.txt: 0.88515
# speech_34.txt: 0.85017
# speech_12.txt: 0.82705
#
# --- Jelinek-Mercer RESULTS ---
# speech_18.txt: 0.001995175287
# speech_43.txt: 0.001100379616
# speech_30.txt: 0.001057838997
# speech_52.txt: 0.000863275973
# speech_19.txt: 0.000813239709
# speech_10.txt: 0.000780685004
# speech_15.txt: 0.000733346847
# speech_24.txt: 0.000699806479
# speech_38.txt: 0.000676752610
# speech_34.txt: 0.000654444820
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: bring us
# ==============================================
#
# --- BM25 RESULTS ---
# speech_29.txt: 0.41760
# speech_36.txt: 0.41739
# speech_0.txt: 0.41547
# speech_25.txt: 0.41389
# speech_3.txt: 0.39806
# speech_16.txt: 0.39677
# speech_32.txt: 0.39182
# speech_15.txt: 0.38596
# speech_41.txt: 0.38436
# speech_46.txt: 0.38396
#
# --- Jelinek-Mercer RESULTS ---
# speech_0.txt: 0.000002736862
# speech_3.txt: 0.000002514969
# speech_29.txt: 0.000002390525
# speech_36.txt: 0.000002340218
# speech_25.txt: 0.000002218626
# speech_16.txt: 0.000002215142
# speech_15.txt: 0.000002195860
# speech_2.txt: 0.000002164977
# speech_46.txt: 0.000002142233
# speech_32.txt: 0.000001995017
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: doral and they
# ==============================================
#
# --- BM25 RESULTS ---
# speech_8.txt: 4.73100
# speech_0.txt: 0.17682
# speech_19.txt: 0.17351
# speech_6.txt: 0.17283
# speech_44.txt: 0.17197
# speech_21.txt: 0.16977
# speech_1.txt: 0.16955
# speech_33.txt: 0.16915
# speech_43.txt: 0.16862
# speech_34.txt: 0.16815
#
# --- Jelinek-Mercer RESULTS ---
# speech_8.txt: 0.000000040030
# speech_0.txt: 0.000000008958
# speech_44.txt: 0.000000006717
# speech_19.txt: 0.000000006619
# speech_6.txt: 0.000000006046
# speech_55.txt: 0.000000005682
# speech_43.txt: 0.000000005656
# speech_33.txt: 0.000000005654
# speech_21.txt: 0.000000005615
# speech_1.txt: 0.000000005514
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: mike
# ==============================================
#
# --- BM25 RESULTS ---
# speech_6.txt: 4.44264
# speech_8.txt: 4.42281
# speech_55.txt: 4.16684
# speech_40.txt: 3.36164
# speech_45.txt: 3.09122
# speech_7.txt: 2.20015
# speech_39.txt: 1.96534
# speech_0.txt: 0.00000
# speech_1.txt: 0.00000
# speech_10.txt: 0.00000
#
# --- Jelinek-Mercer RESULTS ---
# speech_6.txt: 0.001394081363
# speech_8.txt: 0.001252534990
# speech_55.txt: 0.001209227564
# speech_40.txt: 0.000636884521
# speech_45.txt: 0.000585317266
# speech_7.txt: 0.000416049716
# speech_39.txt: 0.000407639157
# speech_0.txt: 0.000300687285
# speech_1.txt: 0.000300687285
# speech_10.txt: 0.000300687285
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: who have
# ==============================================
#
# --- BM25 RESULTS ---
# speech_3.txt: 0.04133
# speech_7.txt: 0.04131
# speech_22.txt: 0.04120
# speech_20.txt: 0.04110
# speech_16.txt: 0.04106
# speech_9.txt: 0.04072
# speech_28.txt: 0.04071
# speech_34.txt: 0.04070
# speech_21.txt: 0.04064
# speech_11.txt: 0.04060
#
# --- Jelinek-Mercer RESULTS ---
# speech_22.txt: 0.000051332566
# speech_28.txt: 0.000048132960
# speech_3.txt: 0.000047286905
# speech_16.txt: 0.000044413613
# speech_7.txt: 0.000043114504
# speech_20.txt: 0.000042976825
# speech_27.txt: 0.000042394564
# speech_21.txt: 0.000041801748
# speech_55.txt: 0.000041389893
# speech_34.txt: 0.000040566108
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: 40 percent an
# ==============================================
#
# --- BM25 RESULTS ---
# speech_31.txt: 2.98665
# speech_26.txt: 2.58924
# speech_43.txt: 2.52387
# speech_14.txt: 2.50893
# speech_8.txt: 2.30533
# speech_18.txt: 2.30335
# speech_35.txt: 2.25996
# speech_6.txt: 2.06108
# speech_40.txt: 1.99667
# speech_0.txt: 1.88530
#
# --- Jelinek-Mercer RESULTS ---
# speech_31.txt: 0.000000001349
# speech_43.txt: 0.000000000874
# speech_12.txt: 0.000000000753
# speech_14.txt: 0.000000000708
# speech_18.txt: 0.000000000638
# speech_35.txt: 0.000000000625
# speech_26.txt: 0.000000000592
# speech_6.txt: 0.000000000582
# speech_38.txt: 0.000000000514
# speech_40.txt: 0.000000000474
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: hillary
# ==============================================
#
# --- BM25 RESULTS ---
# speech_4.txt: 0.19811
# speech_36.txt: 0.19729
# speech_20.txt: 0.19461
# speech_54.txt: 0.19417
# speech_33.txt: 0.19396
# speech_29.txt: 0.19371
# speech_34.txt: 0.19357
# speech_35.txt: 0.19346
# speech_22.txt: 0.19320
# speech_53.txt: 0.19281
#
# --- Jelinek-Mercer RESULTS ---
# speech_4.txt: 0.007564210592
# speech_36.txt: 0.007391634180
# speech_53.txt: 0.007288468881
# speech_29.txt: 0.006382931422
# speech_54.txt: 0.006372581031
# speech_22.txt: 0.006347857004
# speech_33.txt: 0.006345237440
# speech_20.txt: 0.006317638664
# speech_35.txt: 0.006286890764
# speech_34.txt: 0.006201090240
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: make it
# ==============================================
#
# --- BM25 RESULTS ---
# speech_48.txt: 0.16268
# speech_32.txt: 0.16094
# speech_10.txt: 0.16023
# speech_45.txt: 0.16006
# speech_21.txt: 0.15901
# speech_39.txt: 0.15894
# speech_46.txt: 0.15877
# speech_13.txt: 0.15861
# speech_49.txt: 0.15789
# speech_42.txt: 0.15763
#
# --- Jelinek-Mercer RESULTS ---
# speech_0.txt: 0.000037441856
# speech_10.txt: 0.000031553641
# speech_48.txt: 0.000029945721
# speech_19.txt: 0.000029809070
# speech_8.txt: 0.000029478683
# speech_15.txt: 0.000029261358
# speech_42.txt: 0.000029232443
# speech_13.txt: 0.000028633503
# speech_32.txt: 0.000028183931
# speech_46.txt: 0.000028181893
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: jobs more than
# ==============================================
#
# --- BM25 RESULTS ---
# speech_26.txt: 0.60662
# speech_31.txt: 0.60270
# speech_14.txt: 0.59244
# speech_25.txt: 0.59042
# speech_29.txt: 0.58968
# speech_39.txt: 0.58500
# speech_40.txt: 0.57821
# speech_47.txt: 0.57553
# speech_43.txt: 0.57512
# speech_36.txt: 0.57241
#
# --- Jelinek-Mercer RESULTS ---
# speech_31.txt: 0.000000044441
# speech_26.txt: 0.000000035689
# speech_14.txt: 0.000000033560
# speech_25.txt: 0.000000028703
# speech_29.txt: 0.000000028079
# speech_27.txt: 0.000000025256
# speech_39.txt: 0.000000023864
# speech_43.txt: 0.000000022985
# speech_6.txt: 0.000000022406
# speech_40.txt: 0.000000022248
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: thriving
# ==============================================
#
# --- BM25 RESULTS ---
# speech_43.txt: 3.34146
# speech_33.txt: 3.08618
# speech_0.txt: 2.59998
# speech_1.txt: 0.00000
# speech_10.txt: 0.00000
# speech_11.txt: 0.00000
# speech_12.txt: 0.00000
# speech_13.txt: 0.00000
# speech_14.txt: 0.00000
# speech_15.txt: 0.00000
#
# --- Jelinek-Mercer RESULTS ---
# speech_43.txt: 0.000199923083
# speech_33.txt: 0.000164651664
# speech_0.txt: 0.000105261011
# speech_1.txt: 0.000019091256
# speech_10.txt: 0.000019091256
# speech_11.txt: 0.000019091256
# speech_12.txt: 0.000019091256
# speech_13.txt: 0.000019091256
# speech_14.txt: 0.000019091256
# speech_15.txt: 0.000019091256
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: come true
# ==============================================
#
# --- BM25 RESULTS ---
# speech_15.txt: 2.26446
# speech_19.txt: 1.93697
# speech_22.txt: 1.62631
# speech_46.txt: 1.33869
# speech_0.txt: 1.33772
# speech_35.txt: 1.32180
# speech_49.txt: 1.30153
# speech_45.txt: 1.27715
# speech_24.txt: 1.27356
# speech_2.txt: 1.27346
#
# --- Jelinek-Mercer RESULTS ---
# speech_15.txt: 0.000002319212
# speech_19.txt: 0.000000633466
# speech_1.txt: 0.000000569584
# speech_22.txt: 0.000000506641
# speech_35.txt: 0.000000496604
# speech_46.txt: 0.000000473109
# speech_45.txt: 0.000000453815
# speech_33.txt: 0.000000410166
# speech_47.txt: 0.000000407221
# speech_49.txt: 0.000000404628
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: a rally at
# ==============================================
#
# --- BM25 RESULTS ---
# speech_42.txt: 1.40860
# speech_27.txt: 1.27513
# speech_50.txt: 1.24884
# speech_46.txt: 1.24644
# speech_49.txt: 1.24449
# speech_25.txt: 1.23572
# speech_51.txt: 1.21574
# speech_35.txt: 1.20260
# speech_33.txt: 1.17015
# speech_47.txt: 1.16760
#
# --- Jelinek-Mercer RESULTS ---
# speech_42.txt: 0.000000025313
# speech_51.txt: 0.000000018940
# speech_49.txt: 0.000000018838
# speech_46.txt: 0.000000018776
# speech_50.txt: 0.000000018430
# speech_47.txt: 0.000000015753
# speech_27.txt: 0.000000015132
# speech_39.txt: 0.000000015098
# speech_48.txt: 0.000000015035
# speech_40.txt: 0.000000014248
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: afghanistan
# ==============================================
#
# --- BM25 RESULTS ---
# speech_3.txt: 2.05201
# speech_22.txt: 1.81405
# speech_41.txt: 1.64877
# speech_16.txt: 1.64785
# speech_17.txt: 1.56853
# speech_1.txt: 1.56603
# speech_40.txt: 1.50235
# speech_18.txt: 1.47623
# speech_39.txt: 1.47033
# speech_37.txt: 1.39994
#
# --- Jelinek-Mercer RESULTS ---
# speech_3.txt: 0.000256978357
# speech_22.txt: 0.000242010590
# speech_41.txt: 0.000201257720
# speech_16.txt: 0.000201064192
# speech_17.txt: 0.000185554199
# speech_1.txt: 0.000185098264
# speech_40.txt: 0.000174112328
# speech_18.txt: 0.000169921448
# speech_39.txt: 0.000168998454
# speech_37.txt: 0.000158602746
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: of our
# ==============================================
#
# --- BM25 RESULTS ---
# speech_7.txt: 0.04311
# speech_2.txt: 0.04304
# speech_26.txt: 0.04300
# speech_17.txt: 0.04296
# speech_39.txt: 0.04294
# speech_3.txt: 0.04294
# speech_20.txt: 0.04294
# speech_44.txt: 0.04291
# speech_40.txt: 0.04288
# speech_31.txt: 0.04283
#
# --- Jelinek-Mercer RESULTS ---
# speech_38.txt: 0.000410114794
# speech_13.txt: 0.000378098756
# speech_2.txt: 0.000375885466
# speech_22.txt: 0.000372453969
# speech_7.txt: 0.000368517263
# speech_17.txt: 0.000367795429
# speech_26.txt: 0.000360897881
# speech_20.txt: 0.000357737760
# speech_14.txt: 0.000354501639
# speech_39.txt: 0.000354450876
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: companies won t
# ==============================================
#
# --- BM25 RESULTS ---
# speech_48.txt: 2.58648
# speech_49.txt: 2.44613
# speech_2.txt: 2.30061
# speech_6.txt: 2.19102
# speech_45.txt: 2.12024
# speech_47.txt: 2.09127
# speech_43.txt: 2.03763
# speech_50.txt: 1.88160
# speech_52.txt: 1.86782
# speech_19.txt: 1.83426
#
# --- Jelinek-Mercer RESULTS ---
# speech_48.txt: 0.000000002834
# speech_49.txt: 0.000000002459
# speech_6.txt: 0.000000002101
# speech_0.txt: 0.000000001398
# speech_2.txt: 0.000000001355
# speech_19.txt: 0.000000001226
# speech_8.txt: 0.000000001208
# speech_47.txt: 0.000000001186
# speech_43.txt: 0.000000001179
# speech_52.txt: 0.000000001157
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: less
# ==============================================
#
# --- BM25 RESULTS ---
# speech_49.txt: 1.61150
# speech_48.txt: 1.55263
# speech_44.txt: 1.46681
# speech_26.txt: 1.40577
# speech_7.txt: 1.34065
# speech_42.txt: 1.18547
# speech_4.txt: 1.15018
# speech_2.txt: 1.13449
# speech_55.txt: 1.06282
# speech_25.txt: 1.03675
#
# --- Jelinek-Mercer RESULTS ---
# speech_49.txt: 0.000692945239
# speech_48.txt: 0.000603741723
# speech_44.txt: 0.000511166611
# speech_26.txt: 0.000462489927
# speech_42.txt: 0.000437690726
# speech_7.txt: 0.000407318980
# speech_55.txt: 0.000358302176
# speech_4.txt: 0.000351114190
# speech_25.txt: 0.000345798858
# speech_2.txt: 0.000345038814
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: since 1973
# ==============================================
#
# --- BM25 RESULTS ---
# speech_40.txt: 3.41781
# speech_30.txt: 3.40643
# speech_50.txt: 0.34043
# speech_41.txt: 0.33179
# speech_49.txt: 0.32964
# speech_35.txt: 0.32602
# speech_48.txt: 0.32143
# speech_45.txt: 0.32141
# speech_54.txt: 0.32070
# speech_39.txt: 0.31957
#
# --- Jelinek-Mercer RESULTS ---
# speech_40.txt: 0.000000159548
# speech_30.txt: 0.000000134501
# speech_50.txt: 0.000000016071
# speech_49.txt: 0.000000014320
# speech_41.txt: 0.000000014078
# speech_35.txt: 0.000000013637
# speech_48.txt: 0.000000012901
# speech_45.txt: 0.000000012897
# speech_54.txt: 0.000000012796
# speech_46.txt: 0.000000012707
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: ll bring back
# ==============================================
#
# --- BM25 RESULTS ---
# speech_0.txt: 2.28872
# speech_15.txt: 2.10257
# speech_8.txt: 1.90208
# speech_1.txt: 1.90063
# speech_6.txt: 1.85342
# speech_46.txt: 1.77786
# speech_19.txt: 1.75002
# speech_10.txt: 1.73689
# speech_28.txt: 1.67364
# speech_11.txt: 1.65460
#
# --- Jelinek-Mercer RESULTS ---
# speech_0.txt: 0.000000004069
# speech_15.txt: 0.000000003047
# speech_46.txt: 0.000000002360
# speech_28.txt: 0.000000002032
# speech_49.txt: 0.000000001884
# speech_25.txt: 0.000000001682
# speech_45.txt: 0.000000001617
# speech_1.txt: 0.000000001561
# speech_41.txt: 0.000000001502
# speech_48.txt: 0.000000001413
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: one
# ==============================================
#
# --- BM25 RESULTS ---
# speech_16.txt: 0.02015
# speech_11.txt: 0.01983
# speech_12.txt: 0.01973
# speech_19.txt: 0.01964
# speech_15.txt: 0.01963
# speech_14.txt: 0.01952
# speech_17.txt: 0.01951
# speech_1.txt: 0.01950
# speech_36.txt: 0.01942
# speech_38.txt: 0.01942
#
# --- Jelinek-Mercer RESULTS ---
# speech_16.txt: 0.004332653550
# speech_38.txt: 0.004184608824
# speech_15.txt: 0.003989732441
# speech_14.txt: 0.003969520482
# speech_12.txt: 0.003900284233
# speech_11.txt: 0.003863784680
# speech_22.txt: 0.003826119083
# speech_13.txt: 0.003803729860
# speech_17.txt: 0.003744990805
# speech_25.txt: 0.003740044927
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: victory and
# ==============================================
#
# --- BM25 RESULTS ---
# speech_27.txt: 1.65519
# speech_55.txt: 1.45815
# speech_50.txt: 1.44359
# speech_49.txt: 1.43984
# speech_47.txt: 1.37697
# speech_20.txt: 1.27895
# speech_43.txt: 1.08269
# speech_22.txt: 1.08106
# speech_46.txt: 1.06627
# speech_51.txt: 1.03958
#
# --- Jelinek-Mercer RESULTS ---
# speech_27.txt: 0.000027745436
# speech_55.txt: 0.000019615033
# speech_50.txt: 0.000017172768
# speech_49.txt: 0.000016732326
# speech_47.txt: 0.000014190143
# speech_20.txt: 0.000012915219
# speech_22.txt: 0.000012839302
# speech_43.txt: 0.000011628970
# speech_51.txt: 0.000011124206
# speech_35.txt: 0.000011048885
#
# ----------------------------------------------
#
#
# ==============================================
# QUERY: small handful of
# ==============================================
#
# --- BM25 RESULTS ---
# speech_44.txt: 5.99339
# speech_53.txt: 5.35359
# speech_40.txt: 1.14143
# speech_14.txt: 1.06810
# speech_52.txt: 1.05522
# speech_39.txt: 1.02836
# speech_41.txt: 1.00128
# speech_30.txt: 0.95562
# speech_23.txt: 0.95360
# speech_55.txt: 0.93197
#
# --- Jelinek-Mercer RESULTS ---
# speech_53.txt: 0.000000006226
# speech_44.txt: 0.000000004330
# speech_40.txt: 0.000000000433
# speech_14.txt: 0.000000000429
# speech_52.txt: 0.000000000358
# speech_41.txt: 0.000000000325
# speech_39.txt: 0.000000000318
# speech_23.txt: 0.000000000289
# speech_30.txt: 0.000000000278
# speech_55.txt: 0.000000000263
#
# ----------------------------------------------
